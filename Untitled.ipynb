# %%
import pandas as pd
import sqlite3

# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("D:/Formula1.sqlite")
ConsructorDataFrame = pd.read_sql_query("SELECT * from constructors", con)
print(ConsructorDataFrame.head)
print(ConsructorDataFrame.describe)
constructorResualDataFrame = pd.read_sql_query("SELECT * from constructor_results", con)
print(constructorResualDataFrame.head)
print(constructorResualDataFrame.describe)
constructorStandingsDataFrame = pd.read_sql_query("SELECT * from constructor_standings", con)
print(constructorStandingsDataFrame.head)
print(constructorStandingsDataFrame.describe)
DriverDataFrame = pd.read_sql_query("SELECT * from drivers", con)
print(DriverDataFrame.head)
print(DriverDataFrame.describe)
DriverStandingsDataFrame = pd.read_sql_query("SELECT * from driver_standings", con)
print(DriverStandingsDataFrame.head)
print(DriverStandingsDataFrame.describe)
ResualDataFrame = pd.read_sql_query("SELECT * from results", con)
# Out:
# <bound method NDFrame.head of     constructorId constructorRef            name nationality  \
# 0               1        mclaren         McLaren     British
# 1               2     bmw_sauber      BMW Sauber      German
# 2               3       williams        Williams     British
# 3               4        renault         Renault      French
# 4               5     toro_rosso      Toro Rosso     Italian
# ..            ...            ...             ...         ...
# 203           206       marussia        Marussia     Russian
# 204           207       caterham        Caterham   Malaysian
# 205           208       lotus_f1        Lotus F1     British
# 206           209          manor  Manor Marussia     British
# 207           210           haas    Haas F1 Team    American
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren  None
# 1              http://en.wikipedia.org/wiki/BMW_Sauber  None
# ...

# %%
DriverDataFrame.drop(labels='url', axis=1, columns=None, level=None, inplace=False, errors='raise')
DriverDataFrame=DriverDataFrame.fillna(0)
DriverDataFrame
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  07/01/1985
# 1           2         heidfeld         HEI      Nick    Heidfeld  10/05/1977
# 2           3          rosberg      6  ROS      Nico     Rosberg  27/06/1985
# 3           4           alonso     14  ALO  Fernando      Alonso  29/07/1981
# 4           5       kovalainen         KOV    Heikki  Kovalainen  19/10/1981
# ..        ...              ...    ...  ...       ...         ...         ...
# 837       839             ocon     31  OCO   Esteban        Ocon  17/09/1996
# 838       840           stroll     18  STR     Lance      Stroll  29/10/1998
# 839       841       giovinazzi     36  GIO   Antonio  Giovinazzi  14/12/1993
# 840       842            gasly     10  GAS    Pierre       Gasly  07/02/1996
# 841       843  brendon_hartley     39  HAR   Brendon     Hartley  10/11/1989
#
# ...

# %%
#ars = {'Brand': ['Honda Civic','Toyota Corolla','Ford Focus','Audi A4'],'Price': [22000,25000,27000,35000]}

#f = pd.DataFrame(cars, columns = ['Brand', 'Price'])
MergesqlDataFrame = pd.read_sql_query("SELECT dd.*,rr.*,cr.*,sum(cr.points) as sumpoints from drivers dd join results rr on rr.driverId=dd.driverId join constructor_results cr on rr.raceid =cr.raceid  group by cr.raceid",con)
MergesqlDataFrame
# Out:
#      driverId       driverRef number code   forename     surname         dob  \
# 0          18          button     22  BUT     Jenson      Button  19/01/1980
# 1          18          button     22  BUT     Jenson      Button  19/01/1980
# 2          20          vettel      5  VET  Sebastian      Vettel  03/07/1987
# 3          18          button     22  BUT     Jenson      Button  19/01/1980
# 4          18          button     22  BUT     Jenson      Button  19/01/1980
# ..        ...             ...    ...  ...        ...         ...         ...
# 908         1        hamilton     44  HAM      Lewis    Hamilton  07/01/1985
# 909         1        hamilton     44  HAM      Lewis    Hamilton  07/01/1985
# 910       830  max_verstappen     33  VER        Max  Verstappen  30/09/1997
# 911        20          vettel      5  VET  Sebastian      Vettel  03/07/1987
# 912       822          bottas     77  BOT   Valtteri      Bottas  28/08/1989
#
# ...
